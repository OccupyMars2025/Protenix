# %% [markdown]
# <a href="https://colab.research.google.com/github/OccupyMars2025/Protenix/blob/my-playground/my_playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # study truncnorm

# %%
import numpy as np
from scipy.stats import truncnorm
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)

# %%
a, b = 0.1, 2
mean, var, skew, kurt = truncnorm.stats(a, b, moments='mvsk')

# %%
mean, var, skew, kurt
# Out:
# (np.float64(0.7840519151638217),
#  np.float64(0.22915093676528953),
#  np.float64(0.5695324611275387),
#  np.float64(-0.5986932468150501))

# %%
x = np.linspace(truncnorm.ppf(0.01, a, b),
                truncnorm.ppf(0.99, a, b), 100)

fig, ax = plt.subplots()
ax.plot(x, truncnorm.pdf(x, a, b),
       'r-', lw=5, alpha=0.6, label='truncnorm pdf')

plt.show()

# %%
x
# Out:
# array([0.1110258 , 0.12934721, 0.14766862, 0.16599003, 0.18431144,
#        0.20263285, 0.22095426, 0.23927567, 0.25759708, 0.27591849,
#        0.2942399 , 0.31256131, 0.33088272, 0.34920413, 0.36752554,
#        0.38584695, 0.40416836, 0.42248977, 0.44081118, 0.45913259,
#        0.477454  , 0.49577541, 0.51409682, 0.53241823, 0.55073964,
#        0.56906105, 0.58738246, 0.60570387, 0.62402528, 0.64234669,
#        0.6606681 , 0.67898951, 0.69731092, 0.71563233, 0.73395374,
#        0.75227515, 0.77059656, 0.78891797, 0.80723938, 0.82556079,
#        0.8438822 , 0.86220361, 0.88052502, 0.89884643, 0.91716784,
#        0.93548925, 0.95381066, 0.97213207, 0.99045348, 1.00877489,
#        1.0270963 , 1.04541771, 1.06373912, 1.08206053, 1.10038194,
#        1.11870335, 1.13702476, 1.15534617, 1.17366758, 1.19198899,
#        1.2103104 , 1.22863181, 1.24695322, 1.26527463, 1.28359604,
#        1.30191745, 1.32023886, 1.33856027, 1.35688168, 1.37520309,
# ...

# %%
rv = truncnorm(a, b)
fig, ax = plt.subplots()
ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')
ax.legend()

# %%
vals = truncnorm.ppf([0.001, 0.5, 0.999], a, b)
np.allclose([0.001, 0.5, 0.999], truncnorm.cdf(vals, a, b))
# Out:
# True

# %%
vals
# Out:
# array([0.10110201, 0.70161019, 1.99196309])

# %%
r = truncnorm.rvs(a, b, size=1000)

# %%
r.min(), r.max()
# Out:
# (np.float64(0.10142199270731156), np.float64(1.9965316095965626))

# %%
fig, ax = plt.subplots()
ax.hist(r, density=True, bins='auto', histtype='stepfilled', alpha=0.2)
ax.set_xlim([x[0], x[-1]])
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# /tmp/ipython-input-22-532001234.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='best', frameon=False)

# %%
a = -2
b = 2
truncnorm.std(a=a, b=b, loc=0, scale=1)
# Out:
# np.float64(0.8796256610342398)

# %%
truncnorm.mean(a=a, b=b, loc=0, scale=1)
# Out:
# np.float64(0.0)
