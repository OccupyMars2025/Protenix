# %% [markdown]
# <a href="https://colab.research.google.com/github/OccupyMars2025/Protenix/blob/my-playground/my-playground-run-protenix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone --branch my-playground --single-branch https://github.com/OccupyMars2025/Protenix
# Out:
# Cloning into 'Protenix'...
# remote: Enumerating objects: 1359, done.
# remote: Counting objects: 100% (502/502), done.
# remote: Compressing objects: 100% (231/231), done.
# remote: Total 1359 (delta 362), reused 297 (delta 271), pack-reused 857 (from 2)
# Receiving objects: 100% (1359/1359), 75.23 MiB | 21.95 MiB/s, done.
# Resolving deltas: 100% (773/773), done.

# %%
# !pip install pdbeccdutils
# Out:
# Requirement already satisfied: pdbeccdutils in /usr/local/lib/python3.11/dist-packages (0.8.6)
# Requirement already satisfied: gemmi<0.7.0,>=0.6.6 in /usr/local/lib/python3.11/dist-packages (from pdbeccdutils) (0.6.7)
# Requirement already satisfied: networkx<4.0,>=3.3 in /usr/local/lib/python3.11/dist-packages (from pdbeccdutils) (3.5)
# Requirement already satisfied: numpy<1.27.0,>=1.26.4 in /usr/local/lib/python3.11/dist-packages (from pdbeccdutils) (1.26.4)
# Requirement already satisfied: pillow<11.0.0,>=10.4.0 in /usr/local/lib/python3.11/dist-packages (from pdbeccdutils) (10.4.0)
# Requirement already satisfied: rdkit==2023.9.6 in /usr/local/lib/python3.11/dist-packages (from pdbeccdutils) (2023.9.6)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.11/dist-packages (from pdbeccdutils) (2.32.3)
# Requirement already satisfied: scipy<2.0.0,>=1.14.1 in /usr/local/lib/python3.11/dist-packages (from pdbeccdutils) (1.15.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.3->pdbeccdutils) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.3->pdbeccdutils) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.3->pdbeccdutils) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.3->pdbeccdutils) (2025.6.15)

# %%
# !pip install gemmi
# Out:
# Requirement already satisfied: gemmi in /usr/local/lib/python3.11/dist-packages (0.6.7)

# %%
import os
os.chdir("Protenix")

# %%
# !pwd
# Out:
# /content/Protenix

# %%
# !python3 setup.py develop --cpu
# Out:
# running develop
# /usr/local/lib/python3.11/dist-packages/setuptools/command/develop.py:41: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   easy_install.initialize_options(self)
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running egg_info
# creating protenix.egg-info
# writing protenix.egg-info/PKG-INFO
# writing dependency_links to protenix.egg-info/dependency_links.txt
# writing entry points to protenix.egg-info/entry_points.txt
# writing requirements to protenix.egg-info/requires.txt
# writing top-level names to protenix.egg-info/top_level.txt
# writing manifest file 'protenix.egg-info/SOURCES.txt'
# reading manifest file 'protenix.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'protenix.egg-info/SOURCES.txt'
# running build_ext
# Creating /usr/local/lib/python3.11/dist-packages/protenix.egg-link (link to .)
# Adding protenix 0.5.2 to easy-install.pth file
# Installing protenix script to /usr/local/bin
#
# Installed /content/Protenix
# Processing dependencies for protenix==0.5.2
# Searching for torch==2.3.1
# Reading https://pypi.org/simple/torch/
# Downloading https://files.pythonhosted.org/packages/07/9a/4c5e74264439837814656201da13a898056a5201c976ef042544bceb840f/torch-2.3.1-cp311-cp311-manylinux1_x86_64.whl#sha256=b2ec81b61bb094ea4a9dee1cd3f7b76a44555375719ad29f05c0ca8ef596ad39
# Best match: torch 2.3.1
# Processing torch-2.3.1-cp311-cp311-manylinux1_x86_64.whl
# Installing torch-2.3.1-cp311-cp311-manylinux1_x86_64.whl to /usr/local/lib/python3.11/dist-packages
# Adding torch 2.3.1 to easy-install.pth file
# Installing convert-caffe2-to-onnx script to /usr/local/bin
# Installing convert-onnx-to-caffe2 script to /usr/local/bin
# Installing torchrun script to /usr/local/bin
#
# Installed /usr/local/lib/python3.11/dist-packages/torch-2.3.1-py3.11-linux-x86_64.egg
# Searching for py3Dmol
# Reading https://pypi.org/simple/py3Dmol/
# Downloading https://files.pythonhosted.org/packages/7f/8b/e2a3faa7ddf03a7ace87ae99a87eee1220d33e33cb42cba246215621f408/py3dmol-2.5.1-py2.py3-none-any.whl#sha256=d17bb829bee1ec63f43c7d89c413976b28f3cfbea55bd04d64ddd7c52d402f17
# Best match: py3dmol 2.5.1
# Processing py3dmol-2.5.1-py2.py3-none-any.whl
# Installing py3dmol-2.5.1-py2.py3-none-any.whl to /usr/local/lib/python3.11/dist-packages
# Adding py3dmol 2.5.1 to easy-install.pth file
# detected new path './torch-2.3.1-py3.11-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/py3dmol-2.5.1-py3.11.egg
# Searching for matplotlib==3.9.2
# Reading https://pypi.org/simple/matplotlib/
# Downloading https://files.pythonhosted.org/packages/01/75/6c7ce560e95714a10fcbb3367d1304975a1a3e620f72af28921b796403f3/matplotlib-3.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=8912ef7c2362f7193b5819d17dae8629b34a95c58603d781329712ada83f9447
# Best match: matplotlib 3.9.2
# Processing matplotlib-3.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing matplotlib-3.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl to /usr/local/lib/python3.11/dist-packages
# Adding matplotlib 3.9.2 to easy-install.pth file
# detected new path './py3dmol-2.5.1-py3.11.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/matplotlib-3.9.2-py3.11-linux-x86_64.egg
# Searching for numpy==1.26.3
# Reading https://pypi.org/simple/numpy/
# Downloading https://files.pythonhosted.org/packages/5a/62/007b63f916aca1d27f5fede933fda3315d931ff9b2c28b9c2cf388cd8edb/numpy-1.26.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=f25e2811a9c932e43943a2615e65fc487a0b6b49218899e62e426e7f0a57eeda
# Best match: numpy 1.26.3
# Processing numpy-1.26.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing numpy-1.26.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl to /usr/local/lib/python3.11/dist-packages
# Adding numpy 1.26.3 to easy-install.pth file
# detected new path './matplotlib-3.9.2-py3.11-linux-x86_64.egg'
# Installing f2py script to /usr/local/bin
#
# Installed /usr/local/lib/python3.11/dist-packages/numpy-1.26.3-py3.11-linux-x86_64.egg
# Searching for ipdb
# Reading https://pypi.org/simple/ipdb/
# Downloading https://files.pythonhosted.org/packages/0c/4c/b075da0092003d9a55cf2ecc1cae9384a1ca4f650d51b00fc59875fe76f6/ipdb-0.13.13-py3-none-any.whl#sha256=45529994741c4ab6d2388bfa5d7b725c2cf7fe9deffabdb8a6113aa5ed449ed4
# Best match: ipdb 0.13.13
# Processing ipdb-0.13.13-py3-none-any.whl
# Installing ipdb-0.13.13-py3-none-any.whl to /usr/local/lib/python3.11/dist-packages
# Adding ipdb 0.13.13 to easy-install.pth file
# detected new path './numpy-1.26.3-py3.11-linux-x86_64.egg'
# Installing ipdb3 script to /usr/local/bin
#
# Installed /usr/local/lib/python3.11/dist-packages/ipdb-0.13.13-py3.11.egg
# Searching for icecream
# Reading https://pypi.org/simple/icecream/
# Downloading https://files.pythonhosted.org/packages/36/0a/9496191b82b2839cc92fc713a5888931ab301dfcc55b9d5a49665cdb2aa5/icecream-2.1.5-py3-none-any.whl#sha256=c020917c5cb180a528dbba170250ccd8b74ebc75f2a7a8e839819bf959b9f80c
# Best match: icecream 2.1.5
# Processing icecream-2.1.5-py3-none-any.whl
# Installing icecream-2.1.5-py3-none-any.whl to /usr/local/lib/python3.11/dist-packages
# Adding icecream 2.1.5 to easy-install.pth file
# detected new path './ipdb-0.13.13-py3.11.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/icecream-2.1.5-py3.11.egg
# Searching for protobuf==3.20.2
# Reading https://pypi.org/simple/protobuf/
# Downloading https://files.pythonhosted.org/packages/8b/e6/2a47ce2eba1aaf287380a44270da897ada03d118a55c19595ec7b4f0831f/protobuf-3.20.2-py2.py3-none-any.whl#sha256=c9cdf251c582c16fd6a9f5e95836c90828d51b0069ad22f463761d27c6c19019
# Best match: protobuf 3.20.2
# Processing protobuf-3.20.2-py2.py3-none-any.whl
# Installing protobuf-3.20.2-py2.py3-none-any.whl to /usr/local/lib/python3.11/dist-packages
# Adding protobuf 3.20.2 to easy-install.pth file
# detected new path './icecream-2.1.5-py3.11.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/protobuf-3.20.2-py3.11.egg
# Searching for deepspeed>=0.15.1
# Reading https://pypi.org/simple/deepspeed/
# Downloading https://files.pythonhosted.org/packages/38/10/a7f63e086c1e1c12e290c98363c748ef5ddd6313fde739d2aeccd5ed0cd4/deepspeed-0.17.1.tar.gz#sha256=6d6e21796982b9e024f489e1c211666cc6c0be6e344751368610b9d2da285d6e
# Best match: deepspeed 0.17.1
# Processing deepspeed-0.17.1.tar.gz
# Writing /tmp/easy_install-sbu6d7qs/deepspeed-0.17.1/setup.cfg
# Running deepspeed-0.17.1/setup.py -q bdist_egg --dist-dir /tmp/easy_install-sbu6d7qs/deepspeed-0.17.1/egg-dist-tmp-4iaosvne
# [2025-06-28 15:35:28,349] [WARNING] [real_accelerator.py:209:get_accelerator] Setting accelerator to CPU. If you have GPU or other accelerator, we were unable to detect it.
# [2025-06-28 15:35:28,379] [INFO] [real_accelerator.py:254:get_accelerator] Setting ds_accelerator to cpu (auto detect)
# [2025-06-28 15:35:28,685] [WARNING] [real_accelerator.py:209:get_accelerator] Setting accelerator to CPU. If you have GPU or other accelerator, we were unable to detect it.
# [2025-06-28 15:35:28,690] [INFO] [real_accelerator.py:254:get_accelerator] Setting ds_accelerator to cpu (auto detect)
# x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -c /tmp/easy_install-sbu6d7qs/deepspeed-0.17.1/temp/tmprlsszgql/test.c -o /tmp/easy_install-sbu6d7qs/deepspeed-0.17.1/temp/tmprlsszgql/test.o
# x86_64-linux-gnu-gcc /tmp/easy_install-sbu6d7qs/deepspeed-0.17.1/temp/tmprlsszgql/test.o -laio -o /tmp/easy_install-sbu6d7qs/deepspeed-0.17.1/temp/tmprlsszgql/a.out
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# [WARNING] Torch did not find cuda available, if cross-compiling or running with cpu only you can ignore this message. Adding compute capability for Pascal, Volta, and Turing (compute capabilities 6.0, 6.1, 6.2)
# DS_BUILD_OPS=0
# x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -c /tmp/easy_install-sbu6d7qs/deepspeed-0.17.1/temp/tmp05f03vbt/test.c -o /tmp/easy_install-sbu6d7qs/deepspeed-0.17.1/temp/tmp05f03vbt/test.o
# x86_64-linux-gnu-gcc /tmp/easy_install-sbu6d7qs/deepspeed-0.17.1/temp/tmp05f03vbt/test.o -laio -o /tmp/easy_install-sbu6d7qs/deepspeed-0.17.1/temp/tmp05f03vbt/a.out
# Install Ops={'deepspeed_not_implemented': False, 'async_io': False, 'deepspeed_ccl_comm': False, 'deepspeed_shm_comm': False, 'cpu_adam': False, 'fused_adam': False}
# fatal: not a git repository (or any of the parent directories): .git
# version=0.17.1, git_hash=unknown, git_branch=unknown
# install_requires=['einops', 'hjson', 'msgpack', 'ninja', 'numpy', 'packaging>=20.0', 'psutil', 'py-cpuinfo', 'pydantic>=2.0.0', 'torch', 'tqdm']
# ext_modules=[]
# warning: no files found matching 'deepspeed/inference/v2/kernels/ragged_ops/libs/*.so'
# warning: no files found matching 'deepspeed/inference/v2/kernels/cutlass_ops/libs/*.so'
# warning: no files found matching '*.hip' under directory 'deepspeed'
# warning: no files found matching '*.cc' under directory 'deepspeed'
# warning: no files found matching '*.tr' under directory 'csrc'
# warning: no files found matching '*.cc' under directory 'csrc'
# warning: no files found matching '*.py' under directory 'benchmarks'
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'deepspeed.autotuning.config_templates' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'deepspeed.autotuning.config_templates' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'deepspeed.autotuning.config_templates' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'deepspeed.autotuning.config_templates' to be distributed and are
#         already explicitly excluding 'deepspeed.autotuning.config_templates' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'deepspeed.inference.v2.kernels.core_ops.cuda_linear.include' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'deepspeed.inference.v2.kernels.core_ops.cuda_linear.include' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'deepspeed.inference.v2.kernels.core_ops.cuda_linear.include' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'deepspeed.inference.v2.kernels.core_ops.cuda_linear.include' to be distributed and are
#         already explicitly excluding 'deepspeed.inference.v2.kernels.core_ops.cuda_linear.include' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'deepspeed.inference.v2.kernels.cutlass_ops.shared_resources' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'deepspeed.inference.v2.kernels.cutlass_ops.shared_resources' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'deepspeed.inference.v2.kernels.cutlass_ops.shared_resources' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'deepspeed.inference.v2.kernels.cutlass_ops.shared_resources' to be distributed and are
#         already explicitly excluding 'deepspeed.inference.v2.kernels.cutlass_ops.shared_resources' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'deepspeed.inference.v2.kernels.includes' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'deepspeed.inference.v2.kernels.includes' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'deepspeed.inference.v2.kernels.includes' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'deepspeed.inference.v2.kernels.includes' to be distributed and are
#         already explicitly excluding 'deepspeed.inference.v2.kernels.includes' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'deepspeed.inference.v2.kernels.ragged_ops.includes' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'deepspeed.inference.v2.kernels.ragged_ops.includes' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'deepspeed.inference.v2.kernels.ragged_ops.includes' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'deepspeed.inference.v2.kernels.ragged_ops.includes' to be distributed and are
#         already explicitly excluding 'deepspeed.inference.v2.kernels.ragged_ops.includes' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'deepspeed.inference.v2.kernels.ragged_ops.ragged_helpers' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'deepspeed.inference.v2.kernels.ragged_ops.ragged_helpers' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'deepspeed.inference.v2.kernels.ragged_ops.ragged_helpers' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'deepspeed.inference.v2.kernels.ragged_ops.ragged_helpers' to be distributed and are
#         already explicitly excluding 'deepspeed.inference.v2.kernels.ragged_ops.ragged_helpers' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'deepspeed.inference.v2.ragged.csrc' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'deepspeed.inference.v2.ragged.csrc' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'deepspeed.inference.v2.ragged.csrc' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'deepspeed.inference.v2.ragged.csrc' to be distributed and are
#         already explicitly excluding 'deepspeed.inference.v2.ragged.csrc' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'deepspeed.inference.v2.ragged.includes' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'deepspeed.inference.v2.ragged.includes' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'deepspeed.inference.v2.ragged.includes' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'deepspeed.inference.v2.ragged.includes' to be distributed and are
#         already explicitly excluding 'deepspeed.inference.v2.ragged.includes' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'deepspeed.ops.csrc.adagrad' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'deepspeed.ops.csrc.adagrad' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'deepspeed.ops.csrc.adagrad' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'deepspeed.ops.csrc.adagrad' to be distributed and are
#         already explicitly excluding 'deepspeed.ops.csrc.adagrad' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'deepspeed.ops.csrc.adam' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'deepspeed.ops.csrc.adam' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'deepspeed.ops.csrc.adam' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'deepspeed.ops.csrc.adam' to be distributed and are
#         already explicitly excluding 'deepspeed.ops.csrc.adam' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'deepspeed.ops.csrc.aio.common' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'deepspeed.ops.csrc.aio.common' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'deepspeed.ops.csrc.aio.common' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'deepspeed.ops.csrc.aio.common' to be distributed and are
#         already explicitly excluding 'deepspeed.ops.csrc.aio.common' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'deepspeed.ops.csrc.aio.py_lib' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'deepspeed.ops.csrc.aio.py_lib' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'deepspeed.ops.csrc.aio.py_lib' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'deepspeed.ops.csrc.aio.py_lib' to be distributed and are
#         already explicitly excluding 'deepspeed.ops.csrc.aio.py_lib' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'deepspeed.ops.csrc.aio.py_test' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'deepspeed.ops.csrc.aio.py_test' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'deepspeed.ops.csrc.aio.py_test' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'deepspeed.ops.csrc.aio.py_test' to be distributed and are
#         already explicitly excluding 'deepspeed.ops.csrc.aio.py_test' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'deepspeed.ops.csrc.compile' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'deepspeed.ops.csrc.compile' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'deepspeed.ops.csrc.compile' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'deepspeed.ops.csrc.compile' to be distributed and are
#         already explicitly excluding 'deepspeed.ops.csrc.compile' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'deepspeed.ops.csrc.cpu.adam' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'deepspeed.ops.csrc.cpu.adam' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'deepspeed.ops.csrc.cpu.adam' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'deepspeed.ops.csrc.cpu.adam' to be distributed and are
#         already explicitly excluding 'deepspeed.ops.csrc.cpu.adam' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'deepspeed.ops.csrc.cpu.comm' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'deepspeed.ops.csrc.cpu.comm' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'deepspeed.ops.csrc.cpu.comm' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'deepspeed.ops.csrc.cpu.comm' to be distributed and are
#         already explicitly excluding 'deepspeed.ops.csrc.cpu.comm' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'deepspeed.ops.csrc.cpu.lion' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'deepspeed.ops.csrc.cpu.lion' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'deepspeed.ops.csrc.cpu.lion' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'deepspeed.ops.csrc.cpu.lion' to be distributed and are
#         already explicitly excluding 'deepspeed.ops.csrc.cpu.lion' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.11/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'deepspeed.ops.csrc.deepspeed4science.evoformer_attn' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'deepspeed.ops.csrc.deepspeed4science.evoformer_attn' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'deepspeed.ops.csrc.deepspeed4science.evoformer_attn' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
# ...
# Searching for triton==2.3.1
# Reading https://pypi.org/simple/triton/
# Downloading https://files.pythonhosted.org/packages/64/16/956b7b9d2ed3a437a1a06792b2ae2e3c49147296ba2f4d59fcee376ded8f/triton-2.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=c9d64ae33bcb3a7a18081e3a746e8cf87ca8623ca13d2c362413ce7a486f893e
# Best match: triton 2.3.1
# Processing triton-2.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing triton-2.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl to /usr/local/lib/python3.11/dist-packages
# Adding triton 2.3.1 to easy-install.pth file
# detected new path './ml_collections-1.1.0-py3.11.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/triton-2.3.1-py3.11-linux-x86_64.egg
# Searching for nvidia-nvtx-cu12==12.1.105
# Reading https://pypi.org/simple/nvidia-nvtx-cu12/
# Downloading https://files.pythonhosted.org/packages/da/d3/8057f0587683ed2fcd4dbfbdfdfa807b9160b809976099d36b8f60d08f03/nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl#sha256=dc21cf308ca5691e7c04d962e213f8a4aa9bbfa23d95412f452254c2caeb09e5
# Best match: nvidia-nvtx-cu12 12.1.105
# Processing nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl
# Installing nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl to /usr/local/lib/python3.11/dist-packages
# Adding nvidia-nvtx-cu12 12.1.105 to easy-install.pth file
# detected new path './triton-2.3.1-py3.11-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/nvidia_nvtx_cu12-12.1.105-py3.11-linux-x86_64.egg
# Searching for nvidia-nccl-cu12==2.20.5
# Reading https://pypi.org/simple/nvidia-nccl-cu12/
# Downloading https://files.pythonhosted.org/packages/4b/2a/0a131f572aa09f741c30ccd45a8e56316e8be8dfc7bc19bf0ab7cfef7b19/nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl#sha256=057f6bf9685f75215d0c53bf3ac4a10b3e6578351de307abad9e18a99182af56
# Best match: nvidia-nccl-cu12 2.20.5
# Processing nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl
# Installing nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl to /usr/local/lib/python3.11/dist-packages
# Adding nvidia-nccl-cu12 2.20.5 to easy-install.pth file
# detected new path './nvidia_nvtx_cu12-12.1.105-py3.11-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/nvidia_nccl_cu12-2.20.5-py3.11-linux-x86_64.egg
# Searching for nvidia-cusparse-cu12==12.1.0.106
# Reading https://pypi.org/simple/nvidia-cusparse-cu12/
# Downloading https://files.pythonhosted.org/packages/65/5b/cfaeebf25cd9fdec14338ccb16f6b2c4c7fa9163aefcf057d86b9cc248bb/nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl#sha256=f3b50f42cf363f86ab21f720998517a659a48131e8d538dc02f8768237bd884c
# Best match: nvidia-cusparse-cu12 12.1.0.106
# Processing nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl
# Installing nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl to /usr/local/lib/python3.11/dist-packages
# Adding nvidia-cusparse-cu12 12.1.0.106 to easy-install.pth file
# detected new path './nvidia_nccl_cu12-2.20.5-py3.11-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/nvidia_cusparse_cu12-12.1.0.106-py3.11-linux-x86_64.egg
# Searching for nvidia-cusolver-cu12==11.4.5.107
# Reading https://pypi.org/simple/nvidia-cusolver-cu12/
# Downloading https://files.pythonhosted.org/packages/bc/1d/8de1e5c67099015c834315e333911273a8c6aaba78923dd1d1e25fc5f217/nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl#sha256=8a7ec542f0412294b15072fa7dab71d31334014a69f953004ea7a118206fe0dd
# Best match: nvidia-cusolver-cu12 11.4.5.107
# Processing nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl
# Installing nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl to /usr/local/lib/python3.11/dist-packages
# Adding nvidia-cusolver-cu12 11.4.5.107 to easy-install.pth file
# detected new path './nvidia_cusparse_cu12-12.1.0.106-py3.11-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/nvidia_cusolver_cu12-11.4.5.107-py3.11-linux-x86_64.egg
# Searching for nvidia-curand-cu12==10.3.2.106
# Reading https://pypi.org/simple/nvidia-curand-cu12/
# Downloading https://files.pythonhosted.org/packages/44/31/4890b1c9abc496303412947fc7dcea3d14861720642b49e8ceed89636705/nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl#sha256=9d264c5036dde4e64f1de8c50ae753237c12e0b1348738169cd0f8a536c0e1e0
# Best match: nvidia-curand-cu12 10.3.2.106
# Processing nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl
# Installing nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl to /usr/local/lib/python3.11/dist-packages
# Adding nvidia-curand-cu12 10.3.2.106 to easy-install.pth file
# detected new path './nvidia_cusolver_cu12-11.4.5.107-py3.11-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/nvidia_curand_cu12-10.3.2.106-py3.11-linux-x86_64.egg
# Searching for nvidia-cufft-cu12==11.0.2.54
# Reading https://pypi.org/simple/nvidia-cufft-cu12/
# Downloading https://files.pythonhosted.org/packages/86/94/eb540db023ce1d162e7bea9f8f5aa781d57c65aed513c33ee9a5123ead4d/nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl#sha256=794e3948a1aa71fd817c3775866943936774d1c14e7628c74f6f7417224cdf56
# Best match: nvidia-cufft-cu12 11.0.2.54
# Processing nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl
# Installing nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl to /usr/local/lib/python3.11/dist-packages
# Adding nvidia-cufft-cu12 11.0.2.54 to easy-install.pth file
# detected new path './nvidia_curand_cu12-10.3.2.106-py3.11-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/nvidia_cufft_cu12-11.0.2.54-py3.11-linux-x86_64.egg
# Searching for nvidia-cublas-cu12==12.1.3.1
# Reading https://pypi.org/simple/nvidia-cublas-cu12/
# Downloading https://files.pythonhosted.org/packages/37/6d/121efd7382d5b0284239f4ab1fc1590d86d34ed4a4a2fdb13b30ca8e5740/nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl#sha256=ee53ccca76a6fc08fb9701aa95b6ceb242cdaab118c3bb152af4e579af792728
# Best match: nvidia-cublas-cu12 12.1.3.1
# Processing nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl
# Installing nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl to /usr/local/lib/python3.11/dist-packages
# Adding nvidia-cublas-cu12 12.1.3.1 to easy-install.pth file
# detected new path './nvidia_cufft_cu12-11.0.2.54-py3.11-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/nvidia_cublas_cu12-12.1.3.1-py3.11-linux-x86_64.egg
# Searching for nvidia-cudnn-cu12==8.9.2.26
# Reading https://pypi.org/simple/nvidia-cudnn-cu12/
# Downloading https://files.pythonhosted.org/packages/ff/74/a2e2be7fb83aaedec84f391f082cf765dfb635e7caa9b49065f73e4835d8/nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl#sha256=5ccb288774fdfb07a7e7025ffec286971c06d8d7b4fb162525334616d7629ff9
# Best match: nvidia-cudnn-cu12 8.9.2.26
# Processing nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl
# Installing nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl to /usr/local/lib/python3.11/dist-packages
# Adding nvidia-cudnn-cu12 8.9.2.26 to easy-install.pth file
# detected new path './nvidia_cublas_cu12-12.1.3.1-py3.11-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/nvidia_cudnn_cu12-8.9.2.26-py3.11-linux-x86_64.egg
# Searching for nvidia-cuda-cupti-cu12==12.1.105
# Reading https://pypi.org/simple/nvidia-cuda-cupti-cu12/
# Downloading https://files.pythonhosted.org/packages/7e/00/6b218edd739ecfc60524e585ba8e6b00554dd908de2c9c66c1af3e44e18d/nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl#sha256=e54fde3983165c624cb79254ae9818a456eb6e87a7fd4d56a2352c24ee542d7e
# Best match: nvidia-cuda-cupti-cu12 12.1.105
# Processing nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl
# Installing nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl to /usr/local/lib/python3.11/dist-packages
# Adding nvidia-cuda-cupti-cu12 12.1.105 to easy-install.pth file
# detected new path './nvidia_cudnn_cu12-8.9.2.26-py3.11-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/nvidia_cuda_cupti_cu12-12.1.105-py3.11-linux-x86_64.egg
# Searching for nvidia-cuda-runtime-cu12==12.1.105
# Reading https://pypi.org/simple/nvidia-cuda-runtime-cu12/
# Downloading https://files.pythonhosted.org/packages/eb/d5/c68b1d2cdfcc59e72e8a5949a37ddb22ae6cade80cd4a57a84d4c8b55472/nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl#sha256=6e258468ddf5796e25f1dc591a31029fa317d97a0a94ed93468fc86301d61e40
# Best match: nvidia-cuda-runtime-cu12 12.1.105
# Processing nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl
# Installing nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl to /usr/local/lib/python3.11/dist-packages
# Adding nvidia-cuda-runtime-cu12 12.1.105 to easy-install.pth file
# detected new path './nvidia_cuda_cupti_cu12-12.1.105-py3.11-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/nvidia_cuda_runtime_cu12-12.1.105-py3.11-linux-x86_64.egg
# Searching for nvidia-cuda-nvrtc-cu12==12.1.105
# Reading https://pypi.org/simple/nvidia-cuda-nvrtc-cu12/
# Downloading https://files.pythonhosted.org/packages/b6/9f/c64c03f49d6fbc56196664d05dba14e3a561038a81a638eeb47f4d4cfd48/nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl#sha256=339b385f50c309763ca65456ec75e17bbefcbbf2893f462cb8b90584cd27a1c2
# Best match: nvidia-cuda-nvrtc-cu12 12.1.105
# Processing nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl
# Installing nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl to /usr/local/lib/python3.11/dist-packages
# Adding nvidia-cuda-nvrtc-cu12 12.1.105 to easy-install.pth file
# detected new path './nvidia_cuda_runtime_cu12-12.1.105-py3.11-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/nvidia_cuda_nvrtc_cu12-12.1.105-py3.11-linux-x86_64.egg
# Searching for asttokens>=2.0.1
# Reading https://pypi.org/simple/asttokens/
# Downloading https://files.pythonhosted.org/packages/25/8a/c46dcc25341b5bce5472c718902eb3d38600a903b14fa6aeecef3f21a46f/asttokens-3.0.0-py3-none-any.whl#sha256=e3078351a059199dd5138cb1c706e6430c05eff2ff136af5eb4790f9d28932e2
# Best match: asttokens 3.0.0
# Processing asttokens-3.0.0-py3-none-any.whl
# Installing asttokens-3.0.0-py3-none-any.whl to /usr/local/lib/python3.11/dist-packages
# Adding asttokens 3.0.0 to easy-install.pth file
# detected new path './nvidia_cuda_nvrtc_cu12-12.1.105-py3.11-linux-x86_64.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/asttokens-3.0.0-py3.11.egg
# Searching for executing>=2.1.0
# Reading https://pypi.org/simple/executing/
# Downloading https://files.pythonhosted.org/packages/7b/8f/c4d9bafc34ad7ad5d8dc16dd1347ee0e507a52c3adb6bfa8887e1c6a26ba/executing-2.2.0-py2.py3-none-any.whl#sha256=11387150cad388d62750327a53d3339fad4888b39a6fe233c3afbb54ecffd3aa
# Best match: executing 2.2.0
# Processing executing-2.2.0-py2.py3-none-any.whl
# Installing executing-2.2.0-py2.py3-none-any.whl to /usr/local/lib/python3.11/dist-packages
# Adding executing 2.2.0 to easy-install.pth file
# detected new path './asttokens-3.0.0-py3.11.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/executing-2.2.0-py3.11.egg
# Searching for colorama>=0.3.9
# Reading https://pypi.org/simple/colorama/
# Downloading https://files.pythonhosted.org/packages/d1/d6/3965ed04c63042e047cb6a3e6ed1a63a35087b6a609aa3a15ed8ac56c221/colorama-0.4.6-py2.py3-none-any.whl#sha256=4f1d9991f5acc0ca119f9d443620b77f9d6b33703e51011c16baf57afb285fc6
# Best match: colorama 0.4.6
# Processing colorama-0.4.6-py2.py3-none-any.whl
# Installing colorama-0.4.6-py2.py3-none-any.whl to /usr/local/lib/python3.11/dist-packages
# Adding colorama 0.4.6 to easy-install.pth file
# detected new path './executing-2.2.0-py3.11.egg'
#
# Installed /usr/local/lib/python3.11/dist-packages/colorama-0.4.6-py3.11.egg
# Searching for ninja
# Reading https://pypi.org/simple/ninja/
# Downloading https://files.pythonhosted.org/packages/eb/7a/455d2877fe6cf99886849c7f9755d897df32eaf3a0fba47b56e615f880f7/ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl#sha256=096487995473320de7f65d622c3f1d16c3ad174797602218ca8c967f51ec38a0
# Best match: ninja 1.11.1.4
# Processing ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl
# Installing ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl to /usr/local/lib/python3.11/dist-packages
# Adding ninja 1.11.1.4 to easy-install.pth file
# detected new path './colorama-0.4.6-py3.11.egg'
# Traceback (most recent call last):
#   File "/content/Protenix/setup.py", line 35, in <module>
#     setup(
#   File "/usr/local/lib/python3.11/dist-packages/setuptools/__init__.py", line 117, in setup
#     return distutils.core.setup(**attrs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/setuptools/_distutils/core.py", line 183, in setup
#     return run_commands(dist)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/setuptools/_distutils/core.py", line 199, in run_commands
#     dist.run_commands()
#   File "/usr/local/lib/python3.11/dist-packages/setuptools/_distutils/dist.py", line 954, in run_commands
#     self.run_command(cmd)
#   File "/usr/local/lib/python3.11/dist-packages/setuptools/dist.py", line 991, in run_command
#     super().run_command(command)
#   File "/usr/local/lib/python3.11/dist-packages/setuptools/_distutils/dist.py", line 973, in run_command
#     cmd_obj.run()
#   File "/usr/local/lib/python3.11/dist-packages/setuptools/command/develop.py", line 35, in run
#     self.install_for_development()
#   File "/usr/local/lib/python3.11/dist-packages/setuptools/command/develop.py", line 127, in install_for_development
#     self.process_distribution(None, self.dist, not self.no_deps)
#   File "/usr/local/lib/python3.11/dist-packages/setuptools/command/easy_install.py", line 788, in process_distribution
#     distros = WorkingSet([]).resolve(
#               ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py", line 897, in resolve
#     dist = self._resolve_dist(
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py", line 933, in _resolve_dist
#     dist = best[req.key] = env.best_match(
#                            ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py", line 1271, in best_match
#     return self.obtain(req, installer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py", line 1307, in obtain
#     return installer(requirement) if installer else None
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/setuptools/command/easy_install.py", line 712, in easy_install
#     return self.install_item(spec, dist.location, tmpdir, deps)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/setuptools/command/easy_install.py", line 739, in install_item
#     self.process_distribution(spec, dist, deps)
#   File "/usr/local/lib/python3.11/dist-packages/setuptools/command/easy_install.py", line 770, in process_distribution
#     self.install_egg_scripts(dist)
#   File "/usr/local/lib/python3.11/dist-packages/setuptools/command/develop.py", line 152, in install_egg_scripts
#     return easy_install.install_egg_scripts(self, dist)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/setuptools/command/easy_install.py", line 639, in install_egg_scripts
#     dist, script_name, dist.get_metadata('scripts/' + script_name)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py", line 1703, in get_metadata
#     return value.decode('utf-8')
#            ^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xac in position 25: invalid start byte in scripts/ninja file at path: /usr/local/lib/python3.11/dist-packages/ninja-1.11.1.4-py3.11-linux-x86_64.egg/EGG-INFO/scripts/ninja

# %%
import os

num_cpus = os.cpu_count()
print(f"Number of CPUs: {num_cpus}")
# Out:
# Number of CPUs: 2

# %%
# !python scripts/gen_ccd_cache.py -c release_data/ccd_cache/ -n 2
# Out:
# --2025-06-28 15:37:29--  https://files.wwpdb.org/pub/pdb/data/monomers/components.cif.gz
# Resolving files.wwpdb.org (files.wwpdb.org)... 13.249.98.4, 13.249.98.48, 13.249.98.73, ...
# Connecting to files.wwpdb.org (files.wwpdb.org)|13.249.98.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 109180315 (104M) [chemical/x-cif]
# Saving to: ‘release_data/ccd_cache/components.cif.gz’
#
# components.cif.gz   100%[===================>] 104.12M  34.8MB/s    in 3.0s
#
# 2025-06-28 15:37:33 (34.8 MB/s) - ‘release_data/ccd_cache/components.cif.gz’ saved [109180315/109180315]
#
#   0% 79/47310 [00:07<1:13:28, 10.71it/s][15:38:04] UFFTYPER: Warning: hybridization set to SP3 for atom 9
#   0% 193/47310 [00:16<1:07:11, 11.69it/s][15:38:13] UFFTYPER: Warning: hybridization set to SP3 for atom 35
#   0% 199/47310 [00:17<1:08:05, 11.53it/s][15:38:14] WARNING: not removing hydrogen atom with neighbor that has non-tetrahedral stereochemistry
#   0% 211/47310 [00:17<1:06:13, 11.85it/s][15:38:15] UFFTYPER: Unrecognized hybridization for atom: 0
# [15:38:15] UFFTYPER: Unrecognized atom type: Ru (0)
#   1% 253/47310 [00:29<1:31:34,  8.56it/s][15:38:26] UFFTYPER: Unrecognized charge state for atom: 65
#   1% 610/47310 [01:43<2:11:49,  5.90it/s][15:39:40] UFFTYPER: Unrecognized atom type: Pt6+2 (0)
# [15:39:40] UFFTYPER: Unrecognized atom type: N_5 (1)
# [15:39:40] UFFTYPER: Unrecognized atom type: N_5 (2)
# [15:39:40] UFFTYPER: Unrecognized atom type: Pt6+2 (15)
# [15:39:40] UFFTYPER: Unrecognized atom type: N_5 (16)
# [15:39:40] UFFTYPER: Unrecognized atom type: N_5 (17)
#   1% 645/47310 [01:45<2:07:36,  6.09it/s][15:39:42] UFFTYPER: Unrecognized atom type: Ru6 (60)
# [15:39:43] UFFTYPER: Unrecognized hybridization for atom: 0
# [15:39:43] UFFTYPER: Unrecognized atom type: Ag+1 (0)
# [15:39:43] UFFTYPER: Unrecognized atom type: Fe5+2 (1)
# [15:39:43] UFFTYPER: Unrecognized atom type: Fe5+2 (2)
# [15:39:43] UFFTYPER: Unrecognized atom type: Fe5+2 (3)
# [15:39:43] UFFTYPER: Unrecognized charge state for atom: 4
# [15:39:43] UFFTYPER: Unrecognized charge state for atom: 5
# [15:39:43] UFFTYPER: Unrecognized charge state for atom: 6
# [15:39:43] UFFTYPER: Unrecognized charge state for atom: 7
#   2% 935/47310 [02:20<1:56:18,  6.65it/s][15:40:17] UFFTYPER: Unrecognized atom type: Cu4+1 (20)
#   2% 965/47310 [02:23<1:55:08,  6.71it/s][15:40:20] UFFTYPER: Unrecognized atom type: S_5+6 (20)
#  91% 42933/47310 [2:35:50<15:53,  4.59it/s]
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/multiprocessing/pool.py", line 856, in next
#     item = self._items.popleft()
#            ^^^^^^^^^^^^^^^^^^^^^
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/Protenix/scripts/gen_ccd_cache.py", line 183, in precompute_ccd_mol
#     for mol in tqdm.tqdm(
#   File "/usr/local/lib/python3.11/dist-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#   File "/usr/lib/python3.11/multiprocessing/pool.py", line 861, in next
#     self._cond.wait(timeout)
#   File "/usr/lib/python3.11/threading.py", line 327, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/Protenix/scripts/gen_ccd_cache.py", line 283, in <module>
#     run_update_ccd_cache(
#   File "/content/Protenix/scripts/gen_ccd_cache.py", line 248, in run_update_ccd_cache
#     precompute_ccd_mol(ccd_cif, ccd_rdkit_mol_pkl, num_cpu=num_cpu)
#   File "/content/Protenix/scripts/gen_ccd_cache.py", line 182, in precompute_ccd_mol
#     with multiprocessing.Pool(num_cpu) as pool:
#   File "/usr/lib/python3.11/multiprocessing/pool.py", line 739, in __exit__
#     self.terminate()
#   File "/usr/lib/python3.11/multiprocessing/pool.py", line 657, in terminate
#     self._terminate()
#   File "/usr/lib/python3.11/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/pool.py", line 690, in _terminate_pool
#     change_notifier.put(None)
#   File "/usr/lib/python3.11/multiprocessing/queues.py", line 371, in put
#     obj = _ForkingPickler.dumps(obj)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/reduction.py", line 51, in dumps
#     cls(buf, protocol).dump(obj)
#     ^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/reduction.py", line 41, in __init__
#     self.dispatch_table.update(self._extra_reducers)
# KeyboardInterrupt
# ^C
